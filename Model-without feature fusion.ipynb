# %%
import pandas as pd
from pathlib import Path

df0_AAA = pd.read_csv(r"D:\myx\Data science project·\outputs\normalized_module_csvs\AAA_normalized1_0.0.csv")
df0_CCC = pd.read_csv(r"D:\myx\Data science project·\outputs\normalized_module_csvs\CCC_normalized1_0.0.csv")
df0_DDD = pd.read_csv(r"D:\myx\Data science project·\outputs\normalized_module_csvs\DDD_normalized1_0.0.csv")
df0_EEE = pd.read_csv(r"D:\myx\Data science project·\outputs\normalized_module_csvs\EEE_normalized1_0.0.csv")
df0_FFF = pd.read_csv(r"D:\myx\Data science project·\outputs\normalized_module_csvs\FFF_normalized1_0.0.csv")
df0_GGG = pd.read_csv(r"D:\myx\Data science project·\outputs\normalized_module_csvs\GGG_normalized1_0.0.csv")
df0_BBB = pd.read_csv(r"D:\myx\Data science project·\outputs\normalized_module_csvs\BBB_normalized1_0.0.csv")
df0_ABCD = pd.concat([df0_AAA, df0_BBB, df0_CCC,df0_DDD], axis=0, ignore_index=True)
df0_CD= pd.concat([df0_CCC,df0_DDD], axis=0, ignore_index=True)

base_path = Path(r"D:\myx\Data science project·\outputs\normalized_module_csvs\fused_scaled")
# 25% 
df25_AAA = pd.read_csv(base_path / "AAA_normalized1_fused_scaled.csv")
df25_BBB = pd.read_csv(base_path / "BBB_normalized1_fused_scaled.csv")
df25_CCC = pd.read_csv(base_path / "CCC_normalized1_fused_scaled.csv")
df25_DDD = pd.read_csv(base_path / "DDD_normalized1_fused_scaled.csv")
df25_EEE = pd.read_csv(base_path / "EEE_normalized1_fused_scaled.csv")
df25_FFF = pd.read_csv(base_path / "FFF_normalized1_fused_scaled.csv")
df25_GGG = pd.read_csv(base_path / "GGG_normalized1_fused_scaled.csv")
df25_ABCD = pd.concat([df25_AAA, df25_BBB, df25_CCC, df25_DDD], axis=0, ignore_index=True)
df25_CD= pd.concat([df25_CCC,df25_DDD], axis=0, ignore_index=True)
# 50%
df50_AAA = pd.read_csv(base_path / "AAA_normalized1_0.5_fused_scaled.csv")
df50_BBB = pd.read_csv(base_path / "BBB_normalized1_0.5_fused_scaled.csv")
df50_CCC = pd.read_csv(base_path / "CCC_normalized1_0.5_fused_scaled.csv")
df50_DDD = pd.read_csv(base_path / "DDD_normalized1_0.5_fused_scaled.csv")
df50_FFF = pd.read_csv(base_path / "FFF_normalized1_0.5_fused_scaled.csv")
df50_ABCD = pd.concat([df50_AAA, df50_BBB, df50_CCC, df50_DDD], axis=0, ignore_index=True)
df50_CD= pd.concat([df50_CCC,df50_DDD], axis=0, ignore_index=True)
# 75% 
df75_AAA = pd.read_csv(base_path / "AAA_normalized1_0.75_fused_scaled.csv")
df75_BBB = pd.read_csv(base_path / "BBB_normalized1_0.75_fused_scaled.csv")
df75_CCC = pd.read_csv(base_path / "CCC_normalized1_0.75_fused_scaled.csv")
df75_DDD = pd.read_csv(base_path / "DDD_normalized1_0.75_fused_scaled.csv")
df75_FFF = pd.read_csv(base_path / "FFF_normalized1_0.75_fused_scaled.csv")
df75_ABCD = pd.concat([df75_AAA, df75_BBB, df75_CCC, df75_DDD], axis=0, ignore_index=True)
df75_CD= pd.concat([df75_CCC,df75_DDD], axis=0, ignore_index=True)

# %%
import pandas as pd

df = pd.read_csv(r"D:\myx\Data science project·\rq1_df1.csv")

result_distribution = df.groupby('code_module')['final_result'].value_counts().unstack().fillna(0).astype(int)

print(result_distribution)
# Out:
# final_result  Distinction  Fail  Pass  Withdrawn
# code_module
# AAA                    44    81   486         74
# BBB                   677  1421  3064        613
# CCC                   498   662  1175        646
# DDD                   382  1184  2217        870
# EEE                   356   401  1288        199
# FFF                   670  1457  2975        841
# GGG                   263   289   730         63

# %%
def get_x_y(df, classification_mode='multi'):
    
    # drop_ivs = ['Unnamed: 0', 'code_module', 'code_presentation', 'id_student',
    #             'final_result', 'date_registration', 'date_unregistration','region']

    drop_ivs = ['Unnamed: 0', 'code_module', 'code_presentation', 'id_student',
                'final_result', 'date_registration', 'date_unregistration']

    # drop_VLE_ivs = [
    #     'n_days_dataplus', 'n_days_glossary', 'n_days_oucollaborate',
    #     'sum_clicks_dataplus', 'sum_clicks_glossary', 'sum_clicks_oucollaborate',
    #     'total_n_days', 'total_sum_clicks', 'module_presentation_length',
    #     'cutoff_day', 'year', 'semester'
    # ]

    drop_VLE_ivs = [
       'n_days_glossary',  'n_days_oucollaborate',
       'n_days_ouelluminate', 
       'n_days_sharedsubpage', 
       'n_days_dataplus', 'n_days_dualpane', 'n_days_repeatactivity', 
 'n_days_externalquiz', 'n_days_folder', 'n_days_htmlactivity',  'n_days_page', 'n_days_questionnaire',
        'sum_clicks_glossary',  'sum_clicks_dataplus', 'sum_clicks_dualpane', 'sum_clicks_externalquiz', 'sum_clicks_folder',
       'sum_clicks_oucollaborate',  'sum_clicks_htmlactivity', 'sum_clicks_page', 'sum_clicks_questionnaire', 
        'sum_clicks_ouelluminate',  
       'sum_clicks_repeatactivity', 'sum_clicks_sharedsubpage', 
        'total_n_days',
       'total_sum_clicks', 'module_presentation_length', 'cutoff_day',
       'year', 'semester', 'V_LPB','V_LCB', 'V_KAB', 'V_ILB']

#     drop_VLE_ivs = [
#        'n_days_glossary',  'n_days_oucollaborate',
#        'n_days_ouelluminate', 
#        'n_days_sharedsubpage', 
#        'n_days_dataplus', 'n_days_dualpane', 'n_days_repeatactivity', 
#  'n_days_externalquiz', 'n_days_folder', 'n_days_htmlactivity', 'n_days_ouwiki', 'n_days_page', 'n_days_questionnaire',
#         'sum_clicks_glossary',  'sum_clicks_dataplus', 'sum_clicks_dualpane', 'sum_clicks_externalquiz', 'sum_clicks_folder',
#        'sum_clicks_oucollaborate',  'sum_clicks_htmlactivity',  'sum_clicks_ouwiki', 'sum_clicks_page', 'sum_clicks_questionnaire', 
#         'sum_clicks_ouelluminate',  
#        'sum_clicks_repeatactivity', 'sum_clicks_sharedsubpage', 
#         'total_n_days',
#        'total_sum_clicks', 'module_presentation_length', 'cutoff_day',
#        'year', 'semester']


#     drop_fused_raw = [
#     'sum_clicks_homepage', 'n_days_homepage',
#     'sum_clicks_resource', 'n_days_resource',
#     'sum_clicks_oucontent', 'n_days_oucontent',
#     'sum_clicks_url', 'n_days_url',
#     'sum_clicks_forumng', 'n_days_forumng',
#     'sum_clicks_ouwiki', 'n_days_ouwiki',
#     'sum_clicks_subpage', 'n_days_subpage',
#     'sum_clicks_quiz', 'n_days_quiz'
# ]


    drop_ivs += drop_VLE_ivs
    # drop_ivs += drop_fused_raw

    if classification_mode == 'multi':
        y = df['final_result']
    elif classification_mode == 'pass_fail':
        y = df['final_result'].replace({0: 0, 1: 0, 2: 1, 3: 1})
    elif classification_mode == 'dropout':
        y = df['final_result'].replace({1: 1, 0: 0, 2: 0, 3: 0})
    elif classification_mode == 'drop_fail_pass':
        y = df['final_result'].replace({1: 0, 0: 1, 2: 2, 3: 2})
    else:
        raise ValueError("Invalid classification_mode. Choose from ['multi', 'pass_fail', 'dropout', 'drop_fail_pass']")

    X = df[[col for col in df.columns if col not in drop_ivs]]
    return X, y


def run_model_RF_weighted(df, course_name='RF_AAA', classification_mode='dropout'):
    from sklearn.preprocessing import label_binarize
    import shap
    import os
    import numpy as np
    import pandas as pd
    import matplotlib.pyplot as plt
    from sklearn.model_selection import train_test_split, GridSearchCV
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.metrics import f1_score, accuracy_score, confusion_matrix, classification_report, roc_auc_score
    from sklearn.metrics import cohen_kappa_score, matthews_corrcoef


    df_train, df_test = train_test_split(df, test_size=0.2, random_state=101, stratify=df['final_result'])


    X_train, y_train = get_x_y(df_train, classification_mode)
    X_test, y_test = get_x_y(df_test, classification_mode)


    class_weights_options = [
     
        'balanced',
       
    ]
    param_grid = {
    'n_estimators': [400, 500, 600],
    'max_features': ['sqrt', 'log2'],
    'max_depth': [5, 7],
    'min_samples_split': [6, 8, 10, 12],
    'bootstrap': [True, False],
    'random_state': [18],
    'class_weight': class_weights_options
}

    

    print("\n Performing grid search with various class_weight settings ...")
    gs = GridSearchCV(RandomForestClassifier(), param_grid=param_grid, cv=5, scoring='f1_weighted', n_jobs=-1)
    gs.fit(X_train, y_train)
    best_model = gs.best_estimator_

    print("\n Best Parameters Found:")
    print(gs.best_params_)
    print("\n Best Class Weight:")
    print(gs.best_params_['class_weight'])

    y_pred = best_model.predict(X_test)
    y_proba = best_model.predict_proba(X_test)

    classes = np.unique(y_test)
    if len(classes) == 2:
        auc = roc_auc_score(y_test, y_proba[:, 1])
    else:
        y_test_bin = label_binarize(y_test, classes=classes)
        auc = roc_auc_score(y_test_bin, y_proba, average="macro", multi_class="ovr")

    base_wd = os.path.normpath(os.getcwd())
    out_dir = os.path.join(base_wd, f"outputs/models/{course_name}/{classification_mode}")
    os.makedirs(out_dir, exist_ok=True)

    y_df = pd.DataFrame({'y_test': y_test, 'y_pred': y_pred}).join(X_test)
    y_df.to_csv(os.path.join(out_dir, "rq1_y_predict.csv"), index=False)

    import joblib

    model_path = os.path.join(out_dir, "rf_model.pkl")
    joblib.dump(best_model, model_path)

    feature_names = list(X_train.columns)
    with open(os.path.join(out_dir, "rf_features.txt"), "w") as f:
        f.write("\n".join(feature_names))

    results = {
        'f1_score_macro': f1_score(y_test, y_pred, average='macro'),
        'f1_score_weighted': f1_score(y_test, y_pred, average='weighted'),
        'accuracy': accuracy_score(y_test, y_pred),
        'auc_score': auc,
        'kappa_score': cohen_kappa_score(y_test, y_pred),
        'mcc_score': matthews_corrcoef(y_test, y_pred),
        'confusion_matrix': confusion_matrix(y_test, y_pred),
        'importances': {f: imp for f, imp in zip(X_train.columns, best_model.feature_importances_)}
    }


    pd.DataFrame.from_dict(results.items()).to_csv(os.path.join(out_dir, "rq1_results.csv"))

    print(f"\n[{course_name} - {classification_mode}] Evaluation:")
    print(f"Macro F1 score:    {results['f1_score_macro']:.4f}")
    print(f"Weighted F1 score: {results['f1_score_weighted']:.4f}")
    print(f"Accuracy:          {results['accuracy']:.4f}")
    print(f"AUC Score:         {results['auc_score']:.4f}")
    print("Confusion Matrix:")
    print(results['confusion_matrix'])
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred))
    print("\nTop 10 Feature Importances:")
    for feat, imp in sorted(results['importances'].items(), key=lambda x: x[1], reverse=True)[:10]:
        print(f"{feat:<30s}: {imp:.6f}")

# %%
#balanced
stage_dict = {
    '0': df0_DDD,
    '25': df25_DDD,
    '50': df50_DDD,
    '75': df75_DDD
}

for stage, df in stage_dict.items():
    print(f"\n\nDropout Classification for Stage {stage}%")
    run_model_RF_weighted(df, course_name=f"RF_DDD_{stage}_change", classification_mode='dropout')

for stage, df in stage_dict.items():
    print(f"\n\npass_fail Classification for Stage {stage}%")
    run_model_RF_weighted(df, course_name=f"RF_DDD_{stage}_change", classification_mode='pass_fail')
# Out:
# Dropout Classification for Stage 0%
#
#  Performing grid search with various class_weight settings ...
#
#  Best Parameters Found:
# {'bootstrap': True, 'class_weight': 'balanced', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_split': 6, 'n_estimators': 600, 'random_state': 18}
#
#  Best Class Weight:
# balanced
#
# [RF_DDD_0_change - dropout] Evaluation:
# Macro F1 score:    0.5379
# Weighted F1 score: 0.6611
# Accuracy:          0.6385
# AUC Score:         0.5838
# Confusion Matrix:
# [[379 160]
#  [ 88  59]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.70      0.75       539
#            1       0.27      0.40      0.32       147
#
#     accuracy                           0.64       686
#    macro avg       0.54      0.55      0.54       686
# weighted avg       0.70      0.64      0.66       686
#
#
# Top 10 Feature Importances:
# imd_band                      : 0.308028
# region                        : 0.303455
# highest_education             : 0.156624
# age_band                      : 0.092305
# disability                    : 0.072261
# gender                        : 0.067327
#
#
# Dropout Classification for Stage 25%
#
#  Performing grid search with various class_weight settings ...
#
#  Best Parameters Found:
# {'bootstrap': True, 'class_weight': 'balanced', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_split': 8, 'n_estimators': 500, 'random_state': 18}
#
#  Best Class Weight:
# balanced
#
# [RF_DDD_25_change - dropout] Evaluation:
# Macro F1 score:    0.6108
# Weighted F1 score: 0.7302
# Accuracy:          0.7063
# AUC Score:         0.6870
# Confusion Matrix:
# [[530 184]
#  [ 75  93]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.74      0.80       714
#            1       0.34      0.55      0.42       168
#
#     accuracy                           0.71       882
#    macro avg       0.61      0.65      0.61       882
# weighted avg       0.77      0.71      0.73       882
#
#
# Top 10 Feature Importances:
# early_score_mean              : 0.250146
# n_days_homepage               : 0.062119
# sum_clicks_subpage            : 0.060982
# sum_clicks_forumng            : 0.057755
# sum_clicks_homepage           : 0.054779
# n_days_subpage                : 0.050527
# sum_clicks_resource           : 0.047407
# n_days_forumng                : 0.046977
# sum_clicks_oucontent          : 0.046766
# n_days_resource               : 0.044502
#
#
# Dropout Classification for Stage 50%
#
#  Performing grid search with various class_weight settings ...
#
#  Best Parameters Found:
# {'bootstrap': True, 'class_weight': 'balanced', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_split': 8, 'n_estimators': 400, 'random_state': 18}
#
#  Best Class Weight:
# balanced
#
# [RF_DDD_50_change - dropout] Evaluation:
# Macro F1 score:    0.6043
# Weighted F1 score: 0.7944
# Accuracy:          0.7713
# AUC Score:         0.7256
# Confusion Matrix:
# [[584 131]
#  [ 57  50]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.82      0.86       715
#            1       0.28      0.47      0.35       107
#
#     accuracy                           0.77       822
#    macro avg       0.59      0.64      0.60       822
# weighted avg       0.83      0.77      0.79       822
#
#
# Top 10 Feature Importances:
# early_score_mean              : 0.249574
# n_days_homepage               : 0.064462
# sum_clicks_subpage            : 0.058555
# sum_clicks_homepage           : 0.056312
# sum_clicks_forumng            : 0.052102
# n_days_oucontent              : 0.049561
# n_days_resource               : 0.048128
# sum_clicks_oucontent          : 0.047553
# n_days_subpage                : 0.047201
# sum_clicks_resource           : 0.045818
#
#
# Dropout Classification for Stage 75%
#
#  Performing grid search with various class_weight settings ...
#
#  Best Parameters Found:
# {'bootstrap': True, 'class_weight': 'balanced', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_split': 6, 'n_estimators': 500, 'random_state': 18}
#
#  Best Class Weight:
# balanced
#
# [RF_DDD_75_change - dropout] Evaluation:
# Macro F1 score:    0.5180
# Weighted F1 score: 0.8939
# Accuracy:          0.8806
# AUC Score:         0.6453
# Confusion Matrix:
# [[659  57]
#  [ 33   5]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94       716
#            1       0.08      0.13      0.10        38
#
#     accuracy                           0.88       754
#    macro avg       0.52      0.53      0.52       754
# weighted avg       0.91      0.88      0.89       754
#
#
# Top 10 Feature Importances:
# early_score_mean              : 0.182754
# sum_clicks_subpage            : 0.069161
# n_days_homepage               : 0.067295
# n_days_oucontent              : 0.063521
# n_days_subpage                : 0.056552
# sum_clicks_oucontent          : 0.056033
# sum_clicks_homepage           : 0.055165
# n_days_resource               : 0.048870
# sum_clicks_forumng            : 0.048214
# n_days_url                    : 0.047649
#
#
# pass_fail Classification for Stage 0%
#
#  Performing grid search with various class_weight settings ...
#
#  Best Parameters Found:
# {'bootstrap': True, 'class_weight': 'balanced', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 500, 'random_state': 18}
#
#  Best Class Weight:
# balanced
#
# [RF_DDD_0_change - pass_fail] Evaluation:
# Macro F1 score:    0.5781
# Weighted F1 score: 0.5838
# Accuracy:          0.5860
# AUC Score:         0.6142
# Confusion Matrix:
# [[154 155]
#  [129 248]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.54      0.50      0.52       309
#            1       0.62      0.66      0.64       377
#
#     accuracy                           0.59       686
#    macro avg       0.58      0.58      0.58       686
# weighted avg       0.58      0.59      0.58       686
#
#
# Top 10 Feature Importances:
# imd_band                      : 0.287873
# highest_education             : 0.255285
# region                        : 0.251639
# age_band                      : 0.085234
# disability                    : 0.069635
# gender                        : 0.050335
#
#
# pass_fail Classification for Stage 25%
#
#  Performing grid search with various class_weight settings ...
#
#  Best Parameters Found:
# {'bootstrap': False, 'class_weight': 'balanced', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_split': 12, 'n_estimators': 600, 'random_state': 18}
#
#  Best Class Weight:
# balanced
#
# [RF_DDD_25_change - pass_fail] Evaluation:
# Macro F1 score:    0.7465
# Weighted F1 score: 0.7486
# Accuracy:          0.7483
# AUC Score:         0.8158
# Confusion Matrix:
# [[293 105]
#  [117 367]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.74      0.73       398
#            1       0.78      0.76      0.77       484
#
#     accuracy                           0.75       882
#    macro avg       0.75      0.75      0.75       882
# weighted avg       0.75      0.75      0.75       882
#
#
# Top 10 Feature Importances:
# early_score_mean              : 0.382434
# n_days_homepage               : 0.100332
# n_days_subpage                : 0.073949
# n_days_resource               : 0.055589
# n_days_forumng                : 0.054534
# sum_clicks_forumng            : 0.048476
# sum_clicks_homepage           : 0.038734
# sum_clicks_resource           : 0.038421
# highest_education             : 0.031228
# sum_clicks_subpage            : 0.025532
#
#
# pass_fail Classification for Stage 50%
#
#  Performing grid search with various class_weight settings ...
#
#  Best Parameters Found:
# {'bootstrap': True, 'class_weight': 'balanced', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_split': 8, 'n_estimators': 600, 'random_state': 18}
#
#  Best Class Weight:
# balanced
#
# [RF_DDD_50_change - pass_fail] Evaluation:
# Macro F1 score:    0.7859
# Weighted F1 score: 0.7909
# Accuracy:          0.7895
# AUC Score:         0.8626
# Confusion Matrix:
# [[271  67]
#  [106 378]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.80      0.76       338
#            1       0.85      0.78      0.81       484
#
#     accuracy                           0.79       822
#    macro avg       0.78      0.79      0.79       822
# weighted avg       0.80      0.79      0.79       822
#
#
# Top 10 Feature Importances:
# early_score_mean              : 0.322983
# n_days_homepage               : 0.117051
# n_days_resource               : 0.073065
# n_days_subpage                : 0.066284
# sum_clicks_homepage           : 0.049340
# n_days_forumng                : 0.047037
# sum_clicks_forumng            : 0.043162
# sum_clicks_resource           : 0.042874
# n_days_oucontent              : 0.036340
# sum_clicks_subpage            : 0.034789
#
#
# pass_fail Classification for Stage 75%
#
#  Performing grid search with various class_weight settings ...
#
#  Best Parameters Found:
# {'bootstrap': True, 'class_weight': 'balanced', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_split': 8, 'n_estimators': 600, 'random_state': 18}
#
#  Best Class Weight:
# balanced
#
# [RF_DDD_75_change - pass_fail] Evaluation:
# Macro F1 score:    0.7879
# Weighted F1 score: 0.8029
# Accuracy:          0.8011
# AUC Score:         0.8795
# Confusion Matrix:
# [[208  62]
#  [ 88 396]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.77      0.73       270
#            1       0.86      0.82      0.84       484
#
#     accuracy                           0.80       754
#    macro avg       0.78      0.79      0.79       754
# weighted avg       0.81      0.80      0.80       754
#
#
# Top 10 Feature Importances:
# early_score_mean              : 0.260212
# n_days_homepage               : 0.147984
# n_days_subpage                : 0.076022
# n_days_resource               : 0.075329
# sum_clicks_homepage           : 0.059551
# n_days_forumng                : 0.053249
# sum_clicks_forumng            : 0.050076
# sum_clicks_subpage            : 0.035222
# n_days_oucontent              : 0.033021
# n_days_url                    : 0.031495

# %%
def run_model_LR_weighted(df, course_name='LR_AAA', classification_mode='dropout'):
    import os
    import numpy as np
    import pandas as pd
    import matplotlib.pyplot as plt
    import joblib
    import shap
    from sklearn.model_selection import train_test_split, GridSearchCV
    from sklearn.linear_model import LogisticRegression
    from sklearn.metrics import (
        f1_score, accuracy_score, confusion_matrix, classification_report,
        roc_auc_score, cohen_kappa_score, matthews_corrcoef
    )
    from sklearn.preprocessing import label_binarize

    df_train, df_test = train_test_split(df, test_size=0.2, random_state=101, stratify=df['final_result'])
    X_train, y_train = get_x_y(df_train, classification_mode)
    X_test, y_test = get_x_y(df_test, classification_mode)

    class_weights_options = [
        
        'balanced'
    ]

    param_grid = {
        'C': [0.01, 0.1, 1, 10],
        'solver': ['liblinear'],  
        'class_weight': class_weights_options,
        'max_iter': [200]
    }

    print("\nPerforming grid search for Logistic Regression")
    gs = GridSearchCV(LogisticRegression(), param_grid=param_grid, cv=5, scoring='f1_weighted', n_jobs=-1)
    gs.fit(X_train, y_train)
    best_model = gs.best_estimator_

    print("\n Best Parameters Found:")
    print(gs.best_params_)

    y_pred = best_model.predict(X_test)
    y_proba = best_model.predict_proba(X_test)

    classes = np.unique(y_test)
    if len(classes) == 2:
        auc = roc_auc_score(y_test, y_proba[:, 1])
    else:
        y_test_bin = label_binarize(y_test, classes=classes)
        auc = roc_auc_score(y_test_bin, y_proba, average="macro", multi_class="ovr")

    out_dir = os.path.join(os.getcwd(), f"outputs/models/{course_name}/{classification_mode}")
    os.makedirs(out_dir, exist_ok=True)

    y_df = pd.DataFrame({'y_test': y_test, 'y_pred': y_pred}).join(X_test)
    y_df.to_csv(os.path.join(out_dir, "rq1_y_predict.csv"), index=False)

    joblib.dump(best_model, os.path.join(out_dir, "lr_model.pkl"))
    with open(os.path.join(out_dir, "lr_features.txt"), "w") as f:
        f.write("\n".join(X_train.columns))

    results = {
        'f1_score_macro': f1_score(y_test, y_pred, average='macro'),
        'f1_score_weighted': f1_score(y_test, y_pred, average='weighted'),
        'accuracy': accuracy_score(y_test, y_pred),
        'auc_score': auc,
        'confusion_matrix': confusion_matrix(y_test, y_pred),
        'coefficients': dict(zip(X_train.columns, best_model.coef_[0]))
    }

    pd.DataFrame.from_dict(results.items()).to_csv(os.path.join(out_dir, "rq1_results.csv"))

    print(f"\n[{course_name} - {classification_mode}] Evaluation:")
    print(f"Macro F1 score:    {results['f1_score_macro']:.4f}")
    print(f"Weighted F1 score: {results['f1_score_weighted']:.4f}")
    print(f"Accuracy:          {results['accuracy']:.4f}")
    print(f"AUC Score:         {results['auc_score']:.4f}")
    print("Confusion Matrix:")
    print(results['confusion_matrix'])

    print("\nClassification Report:")
    print(classification_report(y_test, y_pred))

    print("\nTop 10 Feature Coefficients:")
    for feat, coef in sorted(results['coefficients'].items(), key=lambda x: abs(x[1]), reverse=True)[:10]:
        print(f"{feat:<30s}: {coef:.6f}")

# %%
#balanced
stage_dict = {
    '0': df0_DDD,
    '25': df25_DDD,
    '50': df50_DDD,
    '75': df75_DDD
}

for stage, df in stage_dict.items():
    print(f"\n\nDropout Classification for Stage {stage}%")
    run_model_LR_weighted(df, course_name=f"LR_DDD_{stage}_change", classification_mode='dropout')

for stage, df in stage_dict.items():
    print(f"\n\npass_fail Classification for Stage {stage}%")
    run_model_LR_weighted(df, course_name=f"LR_DDD_{stage}_change", classification_mode='pass_fail')
# Out:
# Dropout Classification for Stage 0%
#
# Performing grid search for Logistic Regression
#
#  Best Parameters Found:
# {'C': 0.01, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'liblinear'}
#
# [LR_DDD_0_change - dropout] Evaluation:
# Macro F1 score:    0.5544
# Weighted F1 score: 0.6724
# Accuracy:          0.6501
# AUC Score:         0.5998
# Confusion Matrix:
# [[382 157]
#  [ 83  64]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.71      0.76       539
#            1       0.29      0.44      0.35       147
#
#     accuracy                           0.65       686
#    macro avg       0.56      0.57      0.55       686
# weighted avg       0.71      0.65      0.67       686
#
#
# Top 10 Feature Coefficients:
# imd_band                      : -0.234305
# disability                    : 0.225694
# highest_education             : -0.098988
# gender                        : -0.091720
# region                        : 0.032746
# age_band                      : -0.029522
#
#
# Dropout Classification for Stage 25%
#
# Performing grid search for Logistic Regression
#
#  Best Parameters Found:
# {'C': 0.01, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'liblinear'}
#
# [LR_DDD_25_change - dropout] Evaluation:
# Macro F1 score:    0.5510
# Weighted F1 score: 0.6767
# Accuracy:          0.6429
# AUC Score:         0.6338
# Confusion Matrix:
# [[483 231]
#  [ 84  84]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.68      0.75       714
#            1       0.27      0.50      0.35       168
#
#     accuracy                           0.64       882
#    macro avg       0.56      0.59      0.55       882
# weighted avg       0.74      0.64      0.68       882
#
#
# Top 10 Feature Coefficients:
# early_score_mean              : -0.411475
# disability                    : 0.286324
# n_days_forumng                : -0.186494
# n_days_subpage                : -0.163668
# region                        : 0.161652
# n_days_homepage               : -0.142013
# gender                        : -0.137726
# n_days_resource               : -0.134150
# n_days_oucontent              : -0.109841
# sum_clicks_forumng            : -0.092476
#
#
# Dropout Classification for Stage 50%
#
# Performing grid search for Logistic Regression
#
#  Best Parameters Found:
# {'C': 10, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'liblinear'}
#
# [LR_DDD_50_change - dropout] Evaluation:
# Macro F1 score:    0.5523
# Weighted F1 score: 0.7142
# Accuracy:          0.6594
# AUC Score:         0.7065
# Confusion Matrix:
# [[472 243]
#  [ 37  70]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.66      0.77       715
#            1       0.22      0.65      0.33       107
#
#     accuracy                           0.66       822
#    macro avg       0.58      0.66      0.55       822
# weighted avg       0.84      0.66      0.71       822
#
#
# Top 10 Feature Coefficients:
# early_score_mean              : -4.292595
# n_days_oucontent              : -1.250934
# n_days_resource               : -1.037719
# sum_clicks_url                : 0.779234
# n_days_url                    : -0.647527
# sum_clicks_oucontent          : 0.632088
# disability                    : 0.624893
# age_band                      : 0.589367
# sum_clicks_ouwiki             : 0.571825
# sum_clicks_resource           : 0.486582
#
#
# Dropout Classification for Stage 75%
#
# Performing grid search for Logistic Regression
#
#  Best Parameters Found:
# {'C': 0.1, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'liblinear'}
#
# [LR_DDD_75_change - dropout] Evaluation:
# Macro F1 score:    0.4759
# Weighted F1 score: 0.7741
# Accuracy:          0.6857
# AUC Score:         0.6797
# Confusion Matrix:
# [[497 219]
#  [ 18  20]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.69      0.81       716
#            1       0.08      0.53      0.14        38
#
#     accuracy                           0.69       754
#    macro avg       0.52      0.61      0.48       754
# weighted avg       0.92      0.69      0.77       754
#
#
# Top 10 Feature Coefficients:
# early_score_mean              : -2.120883
# n_days_subpage                : -0.799170
# sum_clicks_subpage            : 0.764697
# disability                    : 0.700503
# n_days_resource               : -0.596016
# n_days_oucontent              : -0.526640
# n_days_url                    : -0.485066
# highest_education             : 0.482980
# n_days_homepage               : -0.326713
# sum_clicks_url                : 0.295759
#
#
# pass_fail Classification for Stage 0%
#
# Performing grid search for Logistic Regression
#
#  Best Parameters Found:
# {'C': 0.1, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'liblinear'}
#
# [LR_DDD_0_change - pass_fail] Evaluation:
# Macro F1 score:    0.5765
# Weighted F1 score: 0.5804
# Accuracy:          0.5802
# AUC Score:         0.6194
# Confusion Matrix:
# [[167 142]
#  [146 231]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.53      0.54      0.54       309
#            1       0.62      0.61      0.62       377
#
#     accuracy                           0.58       686
#    macro avg       0.58      0.58      0.58       686
# weighted avg       0.58      0.58      0.58       686
#
#
# Top 10 Feature Coefficients:
# highest_education             : 0.898013
# imd_band                      : 0.620947
# disability                    : -0.381438
# age_band                      : 0.291973
# region                        : -0.035355
# gender                        : 0.031560
#
#
# pass_fail Classification for Stage 25%
#
# Performing grid search for Logistic Regression
#
#  Best Parameters Found:
# {'C': 10, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'liblinear'}
#
# [LR_DDD_25_change - pass_fail] Evaluation:
# Macro F1 score:    0.7546
# Weighted F1 score: 0.7571
# Accuracy:          0.7574
# AUC Score:         0.8195
# Confusion Matrix:
# [[287 111]
#  [103 381]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.72      0.73       398
#            1       0.77      0.79      0.78       484
#
#     accuracy                           0.76       882
#    macro avg       0.76      0.75      0.75       882
# weighted avg       0.76      0.76      0.76       882
#
#
# Top 10 Feature Coefficients:
# early_score_mean              : 7.455096
# n_days_subpage                : 1.870846
# sum_clicks_homepage           : -1.833031
# n_days_homepage               : 1.758858
# highest_education             : 1.355920
# sum_clicks_subpage            : -0.666142
# n_days_forumng                : 0.607214
# age_band                      : -0.602183
# sum_clicks_url                : -0.560401
# n_days_oucontent              : 0.515219
#
#
# pass_fail Classification for Stage 50%
#
# Performing grid search for Logistic Regression
#
#  Best Parameters Found:
# {'C': 1, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'liblinear'}
#
# [LR_DDD_50_change - pass_fail] Evaluation:
# Macro F1 score:    0.7724
# Weighted F1 score: 0.7776
# Accuracy:          0.7762
# AUC Score:         0.8647
# Confusion Matrix:
# [[266  72]
#  [112 372]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.79      0.74       338
#            1       0.84      0.77      0.80       484
#
#     accuracy                           0.78       822
#    macro avg       0.77      0.78      0.77       822
# weighted avg       0.78      0.78      0.78       822
#
#
# Top 10 Feature Coefficients:
# early_score_mean              : 6.602663
# n_days_homepage               : 2.550450
# sum_clicks_homepage           : -1.825844
# n_days_subpage                : 1.401644
# sum_clicks_url                : -1.398698
# highest_education             : 0.969216
# n_days_resource               : 0.939032
# sum_clicks_subpage            : -0.934201
# n_days_oucontent              : 0.862042
# sum_clicks_oucontent          : -0.751094
#
#
# pass_fail Classification for Stage 75%
#
# Performing grid search for Logistic Regression
#
#  Best Parameters Found:
# {'C': 10, 'class_weight': 'balanced', 'max_iter': 200, 'solver': 'liblinear'}
#
# [LR_DDD_75_change - pass_fail] Evaluation:
# Macro F1 score:    0.7929
# Weighted F1 score: 0.8063
# Accuracy:          0.8037
# AUC Score:         0.8805
# Confusion Matrix:
# [[217  53]
#  [ 95 389]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.80      0.75       270
#            1       0.88      0.80      0.84       484
#
#     accuracy                           0.80       754
#    macro avg       0.79      0.80      0.79       754
# weighted avg       0.81      0.80      0.81       754
#
#
# Top 10 Feature Coefficients:
# early_score_mean              : 7.510018
# n_days_homepage               : 5.913398
# sum_clicks_homepage           : -4.680550
# sum_clicks_url                : -3.789309
# n_days_subpage                : 2.876757
# sum_clicks_subpage            : -2.730279
# sum_clicks_forumng            : 2.547038
# n_days_url                    : 2.501850
# n_days_forumng                : -1.403430
# sum_clicks_resource           : 1.176897

# %%
def run_model_LightGBM_weighted(df, course_name='LGBM_AAA', classification_mode='dropout'):
    import os
    import numpy as np
    import pandas as pd
    import matplotlib.pyplot as plt
    import joblib
    import shap
    import lightgbm as lgb
    from sklearn.model_selection import train_test_split, GridSearchCV
    from sklearn.metrics import (
        f1_score, accuracy_score, confusion_matrix, classification_report,
        roc_auc_score, cohen_kappa_score, matthews_corrcoef
    )
    from sklearn.preprocessing import label_binarize

    df_train, df_test = train_test_split(df, test_size=0.2, random_state=101, stratify=df['final_result'])
    X_train, y_train = get_x_y(df_train, classification_mode)
    X_test, y_test = get_x_y(df_test, classification_mode)

    class_weights_options = [
      
        'balanced',
     ]
    
    param_grid = {
        'n_estimators': [100, 200],
        'learning_rate': [0.05, 0.1],
        'max_depth': [3, 5],
        'class_weight': class_weights_options
    }

    model = lgb.LGBMClassifier(random_state=42)

    print("\n Performing grid search for LightGBM")
    gs = GridSearchCV(model, param_grid=param_grid, cv=5, scoring='f1_weighted', n_jobs=-1)
    gs.fit(X_train, y_train)

    best_model = gs.best_estimator_

    print("\nBest Parameters Found:")
    print(gs.best_params_)

    y_pred = best_model.predict(X_test)
    y_proba = best_model.predict_proba(X_test)

    classes = np.unique(y_test)
    if len(classes) == 2:
        auc = roc_auc_score(y_test, y_proba[:, 1])
    else:
        y_test_bin = label_binarize(y_test, classes=classes)
        auc = roc_auc_score(y_test_bin, y_proba, average="macro", multi_class="ovr")

    out_dir = os.path.join("outputs/models", course_name, classification_mode)
    os.makedirs(out_dir, exist_ok=True)

    y_df = pd.DataFrame({'y_test': y_test, 'y_pred': y_pred}).join(X_test.reset_index(drop=True))
    y_df.to_csv(os.path.join(out_dir, "rq1_y_predict.csv"), index=False)

    joblib.dump(best_model, os.path.join(out_dir, "lgb_model.pkl"))
    with open(os.path.join(out_dir, "lgb_features.txt"), "w") as f:
        f.write("\n".join(X_train.columns))

    results = {
        'f1_score_macro': f1_score(y_test, y_pred, average='macro'),
        'f1_score_weighted': f1_score(y_test, y_pred, average='weighted'),
        'accuracy': accuracy_score(y_test, y_pred),
        'auc_score': auc,
        'confusion_matrix': confusion_matrix(y_test, y_pred),
        'feature_importance': dict(zip(X_train.columns, best_model.feature_importances_))
    }

    pd.DataFrame.from_dict(results.items()).to_csv(os.path.join(out_dir, "rq1_results.csv"), index=False)

    print(f"\n[{course_name} - {classification_mode}] Evaluation:")
    print(f"Macro F1 score:    {results['f1_score_macro']:.4f}")
    print(f"Weighted F1 score: {results['f1_score_weighted']:.4f}")
    print(f"Accuracy:          {results['accuracy']:.4f}")
    print(f"AUC Score:         {results['auc_score']:.4f}")
    print("Confusion Matrix:")
    print(results['confusion_matrix'])

    print("\nClassification Report:")
    print(classification_report(y_test, y_pred))

    print("\nTop 10 Feature Importance:")
    for feat, imp in sorted(results['feature_importance'].items(), key=lambda x: abs(x[1]), reverse=True)[:10]:
        print(f"{feat:<30s}: {imp:.6f}")

# %%
#balanced
stage_dict = {
    '0': df0_DDD,
    '25': df25_DDD,
    '50': df50_DDD,
    '75': df75_DDD
}

for stage, df in stage_dict.items():
    print(f"\n\nDropout Classification for Stage {stage}%")
    run_model_LightGBM_weighted(df, course_name=f"LightGBM_DDD_{stage}_change", classification_mode='dropout')

for stage, df in stage_dict.items():
    print(f"\n\npass_fail Classification for Stage {stage}%")
    run_model_LightGBM_weighted(df, course_name=f"LightGBM_DDD_{stage}_change", classification_mode='pass_fail')
# Out:
# Dropout Classification for Stage 0%
#
#  Performing grid search for LightGBM
# [LightGBM] [Info] Number of positive: 590, number of negative: 2154
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000474 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 35
# [LightGBM] [Info] Number of data points in the train set: 2744, number of used features: 6
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Start training from score 0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# Best Parameters Found:
# {'class_weight': 'balanced', 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}
#
# [LightGBM_DDD_0_change - dropout] Evaluation:
# Macro F1 score:    0.5006
# Weighted F1 score: 0.6092
# Accuracy:          0.5729
# AUC Score:         0.5599
# Confusion Matrix:
# [[327 212]
#  [ 81  66]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.61      0.69       539
#            1       0.24      0.45      0.31       147
#
#     accuracy                           0.57       686
#    macro avg       0.52      0.53      0.50       686
# weighted avg       0.68      0.57      0.61       686
#
#
# Top 10 Feature Importance:
# region                        : 1302.000000
# imd_band                      : 1268.000000
# highest_education             : 568.000000
# gender                        : 326.000000
# age_band                      : 323.000000
# disability                    : 157.000000
#
#
# Dropout Classification for Stage 25%
#
#  Performing grid search for LightGBM
# [LightGBM] [Info] Number of positive: 670, number of negative: 2855
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001261 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1805
# [LightGBM] [Info] Number of data points in the train set: 3525, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Start training from score 0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# Best Parameters Found:
# {'class_weight': 'balanced', 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}
#
# [LightGBM_DDD_25_change - dropout] Evaluation:
# Macro F1 score:    0.6033
# Weighted F1 score: 0.7458
# Accuracy:          0.7370
# AUC Score:         0.6876
# Confusion Matrix:
# [[581 133]
#  [ 99  69]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83       714
#            1       0.34      0.41      0.37       168
#
#     accuracy                           0.74       882
#    macro avg       0.60      0.61      0.60       882
# weighted avg       0.76      0.74      0.75       882
#
#
# Top 10 Feature Importance:
# early_score_mean              : 352.000000
# sum_clicks_subpage            : 319.000000
# sum_clicks_forumng            : 283.000000
# sum_clicks_homepage           : 276.000000
# sum_clicks_oucontent          : 266.000000
# n_days_homepage               : 220.000000
# sum_clicks_resource           : 210.000000
# sum_clicks_url                : 196.000000
# n_days_oucontent              : 188.000000
# n_days_subpage                : 169.000000
#
#
# Dropout Classification for Stage 50%
#
#  Performing grid search for LightGBM
# [LightGBM] [Info] Number of positive: 425, number of negative: 2862
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001092 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2125
# [LightGBM] [Info] Number of data points in the train set: 3287, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=-0.000000
# [LightGBM] [Info] Start training from score -0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# Best Parameters Found:
# {'class_weight': 'balanced', 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}
#
# [LightGBM_DDD_75_change - pass_fail] Evaluation:
# Macro F1 score:    0.7855
# Weighted F1 score: 0.7997
# Accuracy:          0.7971
# AUC Score:         0.8832
# Confusion Matrix:
# [[213  57]
#  [ 96 388]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.79      0.74       270
#            1       0.87      0.80      0.84       484
#
#     accuracy                           0.80       754
#    macro avg       0.78      0.80      0.79       754
# weighted avg       0.81      0.80      0.80       754
#
#
# Top 10 Feature Importance:
# early_score_mean              : 228.000000
# n_days_homepage               : 185.000000
# sum_clicks_url                : 107.000000
# sum_clicks_homepage           : 81.000000
# n_days_oucontent              : 74.000000
# sum_clicks_oucontent          : 74.000000
# n_days_subpage                : 69.000000
# sum_clicks_subpage            : 68.000000
# sum_clicks_ouwiki             : 65.000000
# sum_clicks_resource           : 52.000000

# %%
def run_model_DFFNN_weighted(df,
                              course_name='DFFNN_AAA',
                              classification_mode='dropout',
                              class_weight_option=None
                             ):
    import os
    import numpy as np
    import pandas as pd
    import matplotlib.pyplot as plt
    import joblib
    import shap
    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import MinMaxScaler
    from sklearn.metrics import (
        f1_score, accuracy_score, confusion_matrix, classification_report,
        roc_auc_score, cohen_kappa_score, matthews_corrcoef
    )
    from sklearn.utils.class_weight import compute_class_weight
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import Dense, Dropout
    from tensorflow.keras.callbacks import EarlyStopping

    def prepare_dffnn_data(df, classification_mode):
        X, y = get_x_y(df, classification_mode)
        feature_names = X.columns.tolist()
        scaler = MinMaxScaler()
        X_scaled = scaler.fit_transform(X)
        y_encoded = y.values.reshape(-1, 1)
        return X_scaled, y_encoded, feature_names, np.unique(y)

    def build_dffnn(input_dim, output_dim=1):
        model = Sequential()
        model.add(Dense(128, input_dim=input_dim, activation='relu'))
        model.add(Dropout(0.3))
        model.add(Dense(64, activation='relu'))
        model.add(Dropout(0.3))
        model.add(Dense(output_dim, activation='sigmoid'))
        model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
        return model

    df_train, df_test = train_test_split(df, test_size=0.2, random_state=101, stratify=df['final_result'])
    X_train, y_train, feature_names, class_names = prepare_dffnn_data(df_train, classification_mode)
    X_test, y_test, _, _ = prepare_dffnn_data(df_test, classification_mode)

    if class_weight_option is None:
        class_weight_dict = None
    elif class_weight_option == 'balanced':
        class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y_train.flatten()), y=y_train.flatten())
        class_weight_dict = dict(enumerate(class_weights))
    elif isinstance(class_weight_option, dict):
        class_weight_dict = class_weight_option
    else:
        raise ValueError("error")

    model = build_dffnn(input_dim=X_train.shape[1])
    es = EarlyStopping(monitor='val_accuracy', patience=20, restore_best_weights=True)

    model.fit(X_train, y_train, epochs=200, batch_size=32,
              validation_split=0.1, callbacks=[es], verbose=1,
              class_weight=class_weight_dict)

    y_pred = model.predict(X_test).flatten()
    y_pred_label = (y_pred > 0.5).astype(int)
    y_true_label = y_test.flatten()

    auc = roc_auc_score(y_true_label, y_pred)
    results = {
        'f1_score_macro': f1_score(y_true_label, y_pred_label, average='macro'),
        'f1_score_weighted': f1_score(y_true_label, y_pred_label, average='weighted'),
        'accuracy': accuracy_score(y_true_label, y_pred_label),
        'auc_score': auc,
        'confusion_matrix': confusion_matrix(y_true_label, y_pred_label)
    }


    out_dir = os.path.join("outputs/models", course_name, classification_mode)
    os.makedirs(out_dir, exist_ok=True)
    pd.DataFrame({'y_true': y_true_label, 'y_pred': y_pred_label}).to_csv(os.path.join(out_dir, "dffnn_predictions.csv"), index=False)
    pd.DataFrame.from_dict(results.items()).to_csv(os.path.join(out_dir, "dffnn_results.csv"))
    model.save(os.path.join(out_dir, "dffnn_model.h5"))
    with open(os.path.join(out_dir, "dffnn_features.txt"), "w") as f:
        f.write("\n".join(feature_names))

    print(f"\n[{course_name} - {classification_mode}] Evaluation:")
    print(f"Macro F1 score:    {results['f1_score_macro']:.4f}")
    print(f"Weighted F1 score: {results['f1_score_weighted']:.4f}")
    print(f"Accuracy:          {results['accuracy']:.4f}")
    print(f"AUC Score:         {results['auc_score']:.4f}")
    print("Confusion Matrix:")
    print(results['confusion_matrix'])
    print("\nClassification Report:")
    print(classification_report(y_true_label, y_pred_label))

# %%
stage_dict = {
    '0': df0_DDD,
    '25': df25_DDD,
    '50': df50_DDD,
    '75': df75_DDD
}

class_weights_options = [
    'balanced'
]

classification_mode = 'dropout' 

for stage, df in stage_dict.items():
    for weight in class_weights_options:
        print(f"\n Stage {stage}%  Weight: {weight}")

        model_name = f"DFFNN_DDD_{stage}_balanced"

        run_model_DFFNN_weighted(
            df,
            course_name=model_name,
            classification_mode=classification_mode,
            class_weight_option=weight
        )
# Out:
#  Stage 0%  Weight: balanced
# d:\anaconda\envs\text_analytics\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/200
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.5031 - loss: 0.7123 - val_accuracy: 0.7673 - val_loss: 0.6475
# Epoch 2/200
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6546 - loss: 0.6881 - val_accuracy: 0.5891 - val_loss: 0.6874
# Epoch 3/200
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4500 - loss: 0.7001 - val_accuracy: 0.7127 - val_loss: 0.6433
# Epoch 4/200
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6090 - loss: 0.6952 - val_accuracy: 0.6473 - val_loss: 0.6683
# Epoch 5/200
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6232 - loss: 0.6745 - val_accuracy: 0.5709 - val_loss: 0.6922
# Epoch 6/200
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5773 - loss: 0.6802 - val_accuracy: 0.5855 - val_loss: 0.6878
# Epoch 7/200
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5528 - loss: 0.6861 - val_accuracy: 0.5964 - val_loss: 0.6811
# Epoch 8/200
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5844 - loss: 0.6775 - val_accuracy: 0.5927 - val_loss: 0.6850
# Epoch 9/200
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5951 - loss: 0.6750 - val_accuracy: 0.6218 - val_loss: 0.6705
# Epoch 10/200
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5998 - loss: 0.6749 - val_accuracy: 0.5891 - val_loss: 0.6868
# Epoch 11/200
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6092 - loss: 0.6771 - val_accuracy: 0.6000 - val_loss: 0.6748
# Epoch 12/200
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6319 - loss: 0.6602 - val_accuracy: 0.5891 - val_loss: 0.6900
# Epoch 13/200
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5336 - loss: 0.6950 - val_accuracy: 0.6545 - val_loss: 0.6554
# Epoch 14/200
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6370 - loss: 0.6790 - val_accuracy: 0.5964 - val_loss: 0.6809
# Epoch 15/200
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6006 - loss: 0.6668 - val_accuracy: 0.5818 - val_loss: 0.6779
# Epoch 16/200
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6072 - loss: 0.6890 - val_accuracy: 0.6655 - val_loss: 0.6483
# Epoch 17/200
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6723 - loss: 0.6673 - val_accuracy: 0.6073 - val_loss: 0.6735
# Epoch 18/200
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6251 - loss: 0.6671 - val_accuracy: 0.6073 - val_loss: 0.6737
# Epoch 19/200
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5870 - loss: 0.6941 - val_accuracy: 0.6400 - val_loss: 0.6625
# Epoch 20/200
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5957 - loss: 0.6930 - val_accuracy: 0.6982 - val_loss: 0.6383
# Epoch 21/200
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6612 - loss: 0.6731 - val_accuracy: 0.6000 - val_loss: 0.6760
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [DFFNN_DDD_0_balanced - dropout] Evaluation:
# Macro F1 score:    0.5591
# Weighted F1 score: 0.7350
# Accuracy:          0.7741
# AUC Score:         0.6046
# Confusion Matrix:
# [[505  34]
#  [121  26]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.94      0.87       539
#            1       0.43      0.18      0.25       147
#
#     accuracy                           0.77       686
#    macro avg       0.62      0.56      0.56       686
# weighted avg       0.73      0.77      0.74       686
#
#
#  Stage 25%  Weight: balanced
# d:\anaconda\envs\text_analytics\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6170 - loss: 0.6892 - val_accuracy: 0.7224 - val_loss: 0.6153
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6574 - loss: 0.6785 - val_accuracy: 0.6742 - val_loss: 0.6343
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6702 - loss: 0.6459 - val_accuracy: 0.5892 - val_loss: 0.6692
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5800 - loss: 0.6680 - val_accuracy: 0.7110 - val_loss: 0.6093
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6524 - loss: 0.6499 - val_accuracy: 0.5949 - val_loss: 0.6470
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6241 - loss: 0.6430 - val_accuracy: 0.6997 - val_loss: 0.6080
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6726 - loss: 0.6302 - val_accuracy: 0.4816 - val_loss: 0.7128
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6042 - loss: 0.6410 - val_accuracy: 0.6827 - val_loss: 0.6145
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6621 - loss: 0.6381 - val_accuracy: 0.6459 - val_loss: 0.6360
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6189 - loss: 0.6462 - val_accuracy: 0.6487 - val_loss: 0.6339
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6543 - loss: 0.6241 - val_accuracy: 0.7025 - val_loss: 0.5931
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6429 - loss: 0.6326 - val_accuracy: 0.7394 - val_loss: 0.5649
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6870 - loss: 0.6153 - val_accuracy: 0.6941 - val_loss: 0.6027
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6772 - loss: 0.6052 - val_accuracy: 0.6346 - val_loss: 0.6473
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6549 - loss: 0.6232 - val_accuracy: 0.6431 - val_loss: 0.6333
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6527 - loss: 0.6133 - val_accuracy: 0.6742 - val_loss: 0.6105
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6561 - loss: 0.6089 - val_accuracy: 0.6289 - val_loss: 0.6494
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6374 - loss: 0.6227 - val_accuracy: 0.7025 - val_loss: 0.5715
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6778 - loss: 0.6260 - val_accuracy: 0.6941 - val_loss: 0.5968
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6467 - loss: 0.6111 - val_accuracy: 0.7450 - val_loss: 0.5346
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6834 - loss: 0.6145 - val_accuracy: 0.6912 - val_loss: 0.5838
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6598 - loss: 0.6122 - val_accuracy: 0.6657 - val_loss: 0.6202
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6580 - loss: 0.6197 - val_accuracy: 0.6997 - val_loss: 0.5715
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6651 - loss: 0.6104 - val_accuracy: 0.6629 - val_loss: 0.6129
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6526 - loss: 0.6051 - val_accuracy: 0.6686 - val_loss: 0.6107
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6576 - loss: 0.6077 - val_accuracy: 0.6856 - val_loss: 0.5885
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6918 - loss: 0.5937 - val_accuracy: 0.6799 - val_loss: 0.5818
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6750 - loss: 0.6131 - val_accuracy: 0.6657 - val_loss: 0.5985
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6889 - loss: 0.5815 - val_accuracy: 0.5921 - val_loss: 0.6657
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6757 - loss: 0.5869 - val_accuracy: 0.6431 - val_loss: 0.6076
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6406 - loss: 0.5909 - val_accuracy: 0.6686 - val_loss: 0.5958
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6634 - loss: 0.5882 - val_accuracy: 0.6374 - val_loss: 0.6299
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6553 - loss: 0.5963 - val_accuracy: 0.7082 - val_loss: 0.5475
# Epoch 34/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6748 - loss: 0.6039 - val_accuracy: 0.7280 - val_loss: 0.5382
# Epoch 35/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7036 - loss: 0.6009 - val_accuracy: 0.6799 - val_loss: 0.5922
# Epoch 36/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6611 - loss: 0.5823 - val_accuracy: 0.5524 - val_loss: 0.7027
# Epoch 37/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6722 - loss: 0.5944 - val_accuracy: 0.7054 - val_loss: 0.5487
# Epoch 38/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6880 - loss: 0.5855 - val_accuracy: 0.6572 - val_loss: 0.6030
# Epoch 39/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6737 - loss: 0.5912 - val_accuracy: 0.6261 - val_loss: 0.6259
# Epoch 40/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6557 - loss: 0.5659 - val_accuracy: 0.6487 - val_loss: 0.5964
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [DFFNN_DDD_25_balanced - dropout] Evaluation:
# Macro F1 score:    0.6337
# Weighted F1 score: 0.7574
# Accuracy:          0.7426
# AUC Score:         0.7025
# Confusion Matrix:
# [[568 146]
#  [ 81  87]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.80      0.83       714
#            1       0.37      0.52      0.43       168
#
#     accuracy                           0.74       882
#    macro avg       0.62      0.66      0.63       882
# weighted avg       0.78      0.74      0.76       882
#
#
#  Stage 50%  Weight: balanced
# Epoch 1/200
# d:\anaconda\envs\text_analytics\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5678 - loss: 0.7213 - val_accuracy: 0.8237 - val_loss: 0.5856
# Epoch 2/200
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6799 - loss: 0.6662 - val_accuracy: 0.5653 - val_loss: 0.6949
# Epoch 3/200
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5635 - loss: 0.6808 - val_accuracy: 0.7234 - val_loss: 0.6192
# Epoch 4/200
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6256 - loss: 0.6891 - val_accuracy: 0.7052 - val_loss: 0.6103
# Epoch 5/200
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6222 - loss: 0.6720 - val_accuracy: 0.7416 - val_loss: 0.5836
# Epoch 6/200
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6684 - loss: 0.6419 - val_accuracy: 0.5562 - val_loss: 0.7128
# Epoch 7/200
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5991 - loss: 0.6477 - val_accuracy: 0.7204 - val_loss: 0.6010
# Epoch 8/200
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6452 - loss: 0.6508 - val_accuracy: 0.7477 - val_loss: 0.5694
# Epoch 9/200
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6386 - loss: 0.6549 - val_accuracy: 0.7599 - val_loss: 0.5554
# Epoch 10/200
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6685 - loss: 0.6278 - val_accuracy: 0.7325 - val_loss: 0.5777
# Epoch 11/200
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6472 - loss: 0.6188 - val_accuracy: 0.7325 - val_loss: 0.5702
# Epoch 12/200
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6729 - loss: 0.6188 - val_accuracy: 0.6960 - val_loss: 0.6112
# Epoch 13/200
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6337 - loss: 0.6337 - val_accuracy: 0.7021 - val_loss: 0.5930
# Epoch 14/200
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6637 - loss: 0.6240 - val_accuracy: 0.7720 - val_loss: 0.5405
# Epoch 15/200
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6870 - loss: 0.6255 - val_accuracy: 0.6809 - val_loss: 0.6151
# Epoch 16/200
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6537 - loss: 0.6269 - val_accuracy: 0.7629 - val_loss: 0.5373
# Epoch 17/200
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6638 - loss: 0.6140 - val_accuracy: 0.7143 - val_loss: 0.5803
# Epoch 18/200
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6924 - loss: 0.5976 - val_accuracy: 0.6413 - val_loss: 0.6267
# Epoch 19/200
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6591 - loss: 0.6188 - val_accuracy: 0.6839 - val_loss: 0.5991
# Epoch 20/200
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6413 - loss: 0.6082 - val_accuracy: 0.7447 - val_loss: 0.5433
# Epoch 21/200
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6706 - loss: 0.6024 - val_accuracy: 0.7143 - val_loss: 0.5554
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [DFFNN_DDD_50_balanced - dropout] Evaluation:
# Macro F1 score:    0.5164
# Weighted F1 score: 0.7779
# Accuracy:          0.7749
# AUC Score:         0.6650
# Confusion Matrix:
# [[619  96]
#  [ 89  18]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87       715
#            1       0.16      0.17      0.16       107
#
#     accuracy                           0.77       822
#    macro avg       0.52      0.52      0.52       822
# weighted avg       0.78      0.77      0.78       822
#
#
#  Stage 75%  Weight: balanced
# Epoch 1/200
# d:\anaconda\envs\text_analytics\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8135 - loss: 0.6883 - val_accuracy: 0.7781 - val_loss: 0.5753
# Epoch 2/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5770 - loss: 0.6767 - val_accuracy: 0.6523 - val_loss: 0.6320
# Epoch 3/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7249 - loss: 0.6037 - val_accuracy: 0.6060 - val_loss: 0.6490
# Epoch 4/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5775 - loss: 0.6985 - val_accuracy: 0.7550 - val_loss: 0.5399
# Epoch 5/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6689 - loss: 0.6834 - val_accuracy: 0.6755 - val_loss: 0.5908
# Epoch 6/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6140 - loss: 0.6532 - val_accuracy: 0.7649 - val_loss: 0.5287
# Epoch 7/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7323 - loss: 0.6005 - val_accuracy: 0.5563 - val_loss: 0.6844
# Epoch 8/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5901 - loss: 0.6387 - val_accuracy: 0.7517 - val_loss: 0.5023
# Epoch 9/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6978 - loss: 0.6472 - val_accuracy: 0.6656 - val_loss: 0.5864
# Epoch 10/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6907 - loss: 0.5844 - val_accuracy: 0.6523 - val_loss: 0.6019
# Epoch 11/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6281 - loss: 0.6228 - val_accuracy: 0.7384 - val_loss: 0.5330
# Epoch 12/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6948 - loss: 0.5985 - val_accuracy: 0.6722 - val_loss: 0.6073
# Epoch 13/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6385 - loss: 0.6281 - val_accuracy: 0.3377 - val_loss: 0.8725
# Epoch 14/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5890 - loss: 0.5897 - val_accuracy: 0.7384 - val_loss: 0.5114
# Epoch 15/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7086 - loss: 0.5685 - val_accuracy: 0.5828 - val_loss: 0.6684
# Epoch 16/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6408 - loss: 0.5651 - val_accuracy: 0.5662 - val_loss: 0.6961
# Epoch 17/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5958 - loss: 0.5767 - val_accuracy: 0.7748 - val_loss: 0.4664
# Epoch 18/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7100 - loss: 0.5690 - val_accuracy: 0.7616 - val_loss: 0.4810
# Epoch 19/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6375 - loss: 0.6317 - val_accuracy: 0.6887 - val_loss: 0.5718
# Epoch 20/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6524 - loss: 0.5650 - val_accuracy: 0.6788 - val_loss: 0.5957
# Epoch 21/200
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7067 - loss: 0.5526 - val_accuracy: 0.6159 - val_loss: 0.6588
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [DFFNN_DDD_75_balanced - dropout] Evaluation:
# Macro F1 score:    0.4910
# Weighted F1 score: 0.8358
# Accuracy:          0.7798
# AUC Score:         0.6192
# Confusion Matrix:
# [[578 138]
#  [ 28  10]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.81      0.87       716
#            1       0.07      0.26      0.11        38
#
#     accuracy                           0.78       754
#    macro avg       0.51      0.54      0.49       754
# weighted avg       0.91      0.78      0.84       754
